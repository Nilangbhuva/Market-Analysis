# %%
import pandas as pd

df = pd.read_csv('merged_data.csv')

df
# Out:
#              DATE  GDP(Billion$)  DGS30(in%)  EXUSEU(US/EU)  EXINUS(IN/US)  \
# 0      1990-01-01       5872.701        7.99       0.865600        16.9633
# 1      1990-01-02       5872.701        8.00       0.865600        16.9633
# 2      1990-01-03       5872.701        8.04       0.865600        16.9633
# 3      1990-01-04       5872.701        8.04       0.865600        16.9633
# 4      1990-01-05       5872.701        8.06       0.865600        16.9633
# ...           ...            ...         ...            ...            ...
# 12779  2024-12-27      29387.964        4.76       0.944965        85.0235
# 12780  2024-12-28      29387.964        4.76       0.944965        85.0235
# 12781  2024-12-29      29387.964        4.76       0.944965        85.0235
# 12782  2024-12-30      29387.964        4.76       0.944965        85.0235
# 12783  2024-12-31      29387.964        4.76       0.961760        85.0235
#
#        EXUSRUB(US/RUB)  BBB(in%)  INFLATION MICHIGAN(in%)  \
# ...
